# %% [markdown]
# ## Задание 1
# Создайте записную книжку Python Notebook в которой будет:
# 1. Формулы динамической системы
# 2. Код на Питоне для численного решения динамической системы
# 3. Визуализация траекторий динамической системы. Для многомерных систем можно строить проекции траектории на координатные плоскости.

# %% [markdown]
# ![title](https://wikimedia.org/api/rest_v1/media/math/render/svg/f2c661afc7030ef444c811349ec573a20a3dce61)

# %%
import numpy as np 
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def lorenz(state, t, s=10, r=28, b=8/3):
  x, y, z = state
  return s*(y-x), x*(r-z)-y, x*y-b*z

state_0 = [0, 1, 0] #начальные условия

t_stop = 100
dt = 0.01
iters = int(t_stop/dt)

t = np.linspace(0, t_stop, iters)

sol = odeint(lorenz, state_0, t)

fig = plt.figure(figsize=(16,8))
plt.plot(t, sol[:, 0], 'r', label='x(t)')
plt.plot(t, sol[:, 1], 'g', label='y(t)')
plt.plot(t, sol[:, 2], 'b', label='z(t)')
plt.legend()
plt.show()

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure

x = sol[:, 0]
y = sol[:, 1]
z = sol[:, 2]

p = figure()
p.line(x, z) #проекция

output_notebook()
show(p)
# Out:
#   <div class="bk-root" id="f199c73d-b881-4e39-b6a4-d16570987f2c" data-root-id="1883"></div>
